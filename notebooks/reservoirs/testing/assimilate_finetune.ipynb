# %%
import numpy as np
from tqdm import tqdm
from pathlib import Path

from config import Config, AssimConfig
from train import Trainer

run_path = Path("/nas/cee-water/cjgleason/ted/swot-ml/runs/test/era5_20251022_191238")
assim_path = Path("/nas/cee-water/cjgleason/ted/swot-ml/runs/test/swot_assim.yml")

# %%
from run import train_new_assimilator

cfg, model, log_dir, dataset = train_new_assimilator(run_path, assim_path)

# %%
lr

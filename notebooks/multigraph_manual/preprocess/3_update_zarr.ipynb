# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from tqdm import tqdm

from data import BasinDataLake

save_dir = Path("/nas/cee-water/cjgleason/ted/swot-ml/data/multigraph_manual")
root_dir = save_dir / 'datalakes' / 'training'
store = BasinDataLake(root_dir)

# %%
zarr_path = Path("/scratch4/workspace/tlanghorst_umass_edu-swot-ml-zarr/20251124")
workers = 1
start_date = pd.Timestamp('1980-01-01')
end_date = pd.Timestamp('2024-12-13')

store.export_to_zarr(zarr_path, workers, start_date=start_date, end_date=end_date)
# Out:
# Iterating through basins:   0%|          | 2/1215 [21:06<213:20:08, 633.15s/it]
# basin='BRANA-87170000'
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 start_date = pd.Timestamp('1980-01-01')
#       4 end_date = pd.Timestamp('2024-12-13')
# ----> 6 store.export_to_zarr(zarr_path, workers, start_date=start_date, end_date=end_date)
#
# File /nas/cee-water/cjgleason/ted/swot-ml/src/data/basindatalake.py:665, in BasinDataLake.export_to_zarr(self, zarr_path, workers, basins, sources, start_date, end_date, chunk_days, overwrite)
#     663     except Exception as e:
#     664         print(f"{basin=}")
# --> 665         raise e
#     666 print(f"Wrote data for {count} basins.")
#
# ...
